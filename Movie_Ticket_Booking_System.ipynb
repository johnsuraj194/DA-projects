# %% [markdown]
# <a href="https://colab.research.google.com/github/johnsuraj194/johnsuraj194/blob/main/Movie_Ticket_Booking_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

# this timing function used to select timing for movie 
def timing(a):
    time1 = {
        "1": "10.00-1.00",
        "2": "1.10-4.10",
        "3": "4.20-7.20",
        "4": "7.30-10.30"
    }
    time2 = {
        "1": "10.15-1.15",
        "2": "1.25-4.25",
        "3": "4.35-7.35",
        "4": "7.45-10.45"
    }
    time3 = {
        "1": "10.30-1.30",
        "2": "1.40-4.40",
        "3": "4.50-7.50",
        "4": "8.00-10.45"
    }
    if a == 1:
        print("choose your time:")
        print(time1)
        t = input("select your time:")
        x = time1[t]
        print("successful!, enjoy movie at "+x)
    elif a == 2:
        print("choose your time:")
        print(time2)
        t = input("select your time:")
        x = time2[t]
        print("successful!, enjoy movie at "+x)
    elif a == 3:
        print("choose your time:")
        print(time3)
        t = input("select your time:")
        x = time3[t]
        print("successful!, enjoy movie at "+x) 
    sys.exit("THANK YOU !!")
    return t



# this theater function used to select screen 
def screen():
    print("which screen do you want to watch movie: ")
    print("SCREEN 1")
    print("SCREEN 2")
    print("SCREEN 3")
    print("Back")
    a = input("choose your screen: ")
    tickets = int(input("number of ticket do you want?: "))
    timing(a)

    return a
    return tickets



#this t_movie function is used to select movie name 
def t_movie():
    print("which movie do you want to watch?")
    print("KGF 2 ")
    print("BEAST ")
    print("SPIDERMAN ")
    print("BACK")
    movie =str(input("choose your movie: "))
    if movie == "BACK": 
      t_movie()
    else:
      screen()
    return movie


def center():
    print("which theater do you wish to see movie? ")
    print("SANGAM CINEMAS")
    print("ROHINI")
    print("PVR")
    print("BACK")
    center=input("choose your option: ")
    t_movie()
    return center


def city():
    print("hi welcome to movie ticket booking: ")
    print("where you want to watch movie?: ")
    print("CHENNAI")
    print("BANGALORE")
    print("COIMBATORE")
    place=input("choose your option: ")
    if place =="CHENNAI":
      center()
    elif place =="BANGALORE":
      center()
    elif place =="COIMBATORE":
      center()
    else:
      print("wrong choice")
      city()
    return place



def login(usernames,passwords):
  usernames=[]
  passwords=[]
  password=""
  username=""
  username=input("Enter the username: ")
  password=input("Enter the password: ")
  if password==passwords[usernames.index(username)]:
    print("Welcome")
    city()

  else:
    print("Incorrect")
    login()

def register():
  names=[]
  usernames=[]
  passwords=[]
  names.append(input("Enter the name: "))
  usernames.append(input("Enter the username: "))
  passwords.append(input("Enter the password: "))
  city()
  


account_ans=""
while True:
  account_ans=input("Choose: a) Signup b) login c) Quit ")
  if account_ans=="a":
    register()
  if account_ans=="b":
    password=""
    username=""
    passwords=[]
    usernames=[]
    login(usernames,passwords)
  if account_ans=="c":
    print("THANK YOU")





print(place)
print(center)
print(movie)
print(a)
print(tickets)
print(t)


login()
register()
city()
t_movie()
center()
timing()
# Out:
# Choose: a) Signup b) login c) Quit a
# Enter the name: john
# Enter the username: john
# Enter the password: pass
# hi welcome to movie ticket booking:
# where you want to watch movie?:
# CHENNAI
# BANGALORE
# COIMBATORE
# choose your option: CHENNAI
# which theater do you wish to see movie?
# SANGAM CINEMAS
# ROHINI
# PVR
# BACK
# choose your option: PVR
# which movie do you want to watch?
# KGF 2
# BEAST
# SPIDERMAN
# BACK
# choose your movie: KGF 2
# which screen do you want to watch movie:
# SCREEN 1
# SCREEN 2
# SCREEN 3
# Back
# choose your screen: SCREEN 1
# number of ticket do you want?: 5
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: THANK YOU !!
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
